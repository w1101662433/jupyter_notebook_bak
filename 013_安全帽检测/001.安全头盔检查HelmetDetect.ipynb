# %%
from ultralytics import YOLO

# %%
yolo = YOLO('yolov8n.pt')

# %%
yolo.train(data='config.yaml',epochs=3,workers=1)
# Out:
# Ultralytics YOLOv8.2.9  Python-3.9.8 torch-1.9.0+cu111 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# WARNING  Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
yolo.predict(r"D:\BaiduSyncdisk\jupyter\013_安全帽检测\dataset\Helmet2\source_files\source_files\indianworkers.mp4",save=True,classes=[0,1,2,3,4,7,9])
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/648) D:\BaiduSyncdisk\jupyter\013_\dataset\Helmet2\source_files\source_files\indianworkers.mp4: 384x640 1 , 1 , 18.7ms
# video 1/1 (frame 2/648) D:\BaiduSyncdisk\jupyter\013_\dataset\Helmet2\source_files\source_files\indianworkers.mp4: 384x640 1 , 1 , 23.7ms
# video 1/1 (frame 3/648) D:\BaiduSyncdisk\jupyter\013_\dataset\Helmet2\source_files\source_files\indianworkers.mp4: 384x640 1 , 1 , 25.6ms
# ...

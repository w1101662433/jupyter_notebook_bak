# %%
from mtcnn import MTCNN
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os,sys,gc
import memory_profiler
# %reload_ext memory_profiler
detector = MTCNN()

# %%
# 读取图片
img_path = r"D:\BaiduSyncdisk\jupyter\012_人脸识别\dataset\明星图片\冯提莫\冯提莫_150.jpg"
image = cv2.imdecode(np.fromfile(img_path, dtype=np.uint8), -1)
#image = cv2.imread(img_path)

# 检测图片中的人脸

faces = detector.detect_faces(image)
for face in faces:
    # 获取人脸边界框的坐标
    x, y, width, height = face['box']
    cropped_image  = image[y:y+height, x:x+width]
    # cv2.imwrite('你好.jpg', cropped_image)
    
    cv2.imencode('.jpg', cropped_image)[1].tofile('你好.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step

# %%
def foo():
    # 生成人脸
    img_path = r"D:\BaiduSyncdisk\jupyter\012_人脸识别\dataset\明星图片"
    out_dir = r"D:\BaiduSyncdisk\jupyter\012_人脸识别\dataset\生成的人脸"
    for n_, label in enumerate(os.listdir(img_path)):
        if not 20 <= n_ <= 21:
            continue
            
        print(n_, 'label',label)
        for file_name in os.listdir(os.path.join(img_path,label)):
            file_path = os.path.join(img_path,label,file_name)
            image = cv2.imdecode(np.fromfile(file_path, dtype=np.uint8), -1)
            if image is None:continue
                
            # 检测图片中的人脸
            try:
                faces = detector.detect_faces(image)
            except Exception as e:
                print('error',e)
                print('error_file_path',file_path)
            if not faces:continue
                
            face = faces[0]
            # 获取人脸边界框的坐标
            x, y, width, height = face['box']
            cropped_image  = image[y:y+height, x:x+width]
            if not os.path.exists(os.path.join(out_dir,label)):
                os.mkdir(os.path.join(out_dir,label))
            out_path = os.path.join(out_dir,label, file_name)
            # cv2.imwrite(out_path, cropped_image)
            cv2.imencode('.jpg', cropped_image)[1].tofile(out_path)
            print('保存图片',out_path)

# %%
foo()
# Out:
# 20 label 聂小雨
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 保存图片 D:\BaiduSyncdisk\jupyter\012_人脸识别\dataset\生成的人脸\聂小雨\聂小雨_0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# ...
